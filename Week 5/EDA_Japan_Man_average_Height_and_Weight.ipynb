# %% [markdown]
# <a href="https://colab.research.google.com/github/rakenputra/machine-learning/blob/main/Week%205/EDA_Japan_Man_average_Height_and_Weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Raken Putra Athallah
# 1103204186
# TK-44-02
#
# Mempelajari dan memperdalam EDA (Exploratory Data Analys).Mencoba untuk mengetahui apa saja yang ada didalam dataset dan apakah ada kesimpulan yang dapat diambil dari korelasi feature-feature yang ada di dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#  membaca dataset CSV
path_to_file = '/content/drive/My Drive/Dataset/man.csv'
man = pd.read_csv(path_to_file)
man
# Out:
#      year   category  height_average  height_standard deviation  \
# 0       5   national           111.0                       4.87
# 1       5   Hokkaido           111.3                       4.81
# 2       5     Aomori           111.8                       4.87
# 3       5      Iwate           111.0                       5.08
# 4       5     Miyagi           111.3                       4.90
# ..    ...        ...             ...                        ...
# 619    17   Kumamoto           170.6                       5.89
# 620    17       Oita           170.1                       5.91
# 621    17   Miyazaki           170.1                       6.13
# 622    17  Kagoshima           170.4                       5.60
# 623    17    Okinawa           169.5                       6.08
#
#      body weight _average  body weight _standard deviation
# 0                    19.3                             2.79
# 1                    19.3                             2.83
# ...

# %%
man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   year                             624 non-null    int64
#  1   category                         624 non-null    object
#  2   height_average                   624 non-null    float64
#  3   height_standard deviation        624 non-null    float64
#  4   body weight _average             624 non-null    float64
#  5   body weight _standard deviation  624 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 29.4+ KB

# %%
man.describe()
# Out:
#              year  height_average  height_standard deviation  \
# count  624.000000      624.000000                 624.000000
# mean    11.000000      145.072917                   6.072420
# std      3.744659       20.507207                   0.942226
# min      5.000000      110.000000                   4.460000
# 25%      8.000000      128.000000                   5.350000
# 50%     11.000000      145.900000                   5.900000
# 75%     14.000000      166.000000                   6.662500
# max     17.000000      171.900000                   8.270000
#
#        body weight _average  body weight _standard deviation
# count            624.000000                       624.000000
# mean              40.986218                         7.869792
# std               14.991854                         2.932388
# min               18.900000                         2.300000
# 25%               27.400000                         5.210000
# ...

# %%
# Mengecek missing values
missing_values = man.isnull().sum()

# Menampilkan jumlah missing values untuk setiap kolom
print(missing_values)
# Out:
# year                               0
# category                           0
# height_average                     0
# height_standard deviation          0
# body weight _average               0
# body weight _standard deviation    0
# dtype: int64

# %%
# Melihat ukuran data
ukuran_data = man.shape
print("Ukuran data (baris, kolom):", ukuran_data)
# Out:
# Ukuran data (baris, kolom): (624, 6)

# %%
sns.boxplot(x=man['year'])
# Out:
# <Axes: xlabel='year'>

# %%
sns.boxplot(x=man['height_average'])
# Out:
# <Axes: xlabel='height_average'>

# %%
sns.boxplot(x=man['height_standard deviation'])
# Out:
# <Axes: xlabel='height_standard deviation'>

# %%
sns.boxplot(x=man['body weight _average'])
# Out:
# <Axes: xlabel='body weight _average'>

# %%
sns.boxplot(x=man['body weight _standard deviation'])
# Out:
# <Axes: xlabel='body weight _standard deviation'>

# %%
man
# Out:
#      year   category  height_average  height_standard deviation  \
# 0       5   national           111.0                       4.87
# 1       5   Hokkaido           111.3                       4.81
# 2       5     Aomori           111.8                       4.87
# 3       5      Iwate           111.0                       5.08
# 4       5     Miyagi           111.3                       4.90
# ..    ...        ...             ...                        ...
# 619    17   Kumamoto           170.6                       5.89
# 620    17       Oita           170.1                       5.91
# 621    17   Miyazaki           170.1                       6.13
# 622    17  Kagoshima           170.4                       5.60
# 623    17    Okinawa           169.5                       6.08
#
#      body weight _average  body weight _standard deviation
# 0                    19.3                             2.79
# 1                    19.3                             2.83
# ...

# %%
man.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Pilih fitur numerik yang ingin dianalisis
numerical_features = ['height_average', 'height_standard deviation', 'body weight _average', 'body weight _standard deviation']

# Hitung matriks korelasi antar fitur numerik
correlation_matrix = man[numerical_features].corr()

# Buat heatmap korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap Korelasi Antar Fitur Numerik')
plt.show()

# %%
#mengamati hubungan antar fitur numerik dengan fungsi pairplot()
sns.pairplot(man, diag_kind = 'kde')

# %%
# Pilih fitur numerik yang ingin dianalisis
numerical_features = ['height_average', 'height_standard deviation', 'body weight _average', 'body weight _standard deviation']
categorical_feature = 'category'

# Visualisasi pair plot dengan pewarnaan berdasarkan 'category'
sns.pairplot(man, hue=categorical_feature)
plt.show()

# %% [markdown]
# Dari tahapan-tahapan yang dilakukan ketika melakukan exploratory data analys kita dapat mengetahui apa saja feature yang ada. Apakah feature tersebut termasuk categorical feature atau numerical feature.
#
# Ketika melakukan exploratory data anlalys kita terkadang menmukan dataset memiliki missing value pada suatu feture, dan ada banyak cara untuk mengatasinya seperti menghilangkan feature tersebut jika memang tidak terlalu berpengaruh hingga memasukkna nilai rata-rata atau mean untuk mengisi missing value tersebut.
#
# Kita juga dapat melihat distribusi atau korelasi setiap feature dengan melakukan visualisasi data sperti melihat distribusi feature pada histogram atau melihat korelasi dengan heatmap atau trend pada pairplot
